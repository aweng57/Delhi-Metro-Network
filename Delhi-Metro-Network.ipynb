# %%
import pandas as pd
import folium
import plotly.express as px
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv("Delhi-Metro-Network.csv")

# %%
df.head(10)
# Out:
#    Station ID                   Station Name  Distance from Start (km)  \
# 0           1                       Jhil Mil                      10.3
# 1           2            Welcome [Conn: Red]                      46.8
# 2           3                    DLF Phase 3                      10.0
# 3           4                     Okhla NSIC                      23.8
# 4           5                     Dwarka Mor                      10.2
# 5           6  Dilli Haat INA [Conn: Yellow]                      24.9
# 6           7               Noida Sector 143                      11.5
# 7           8                      Moolchand                      15.1
# 8           9                   Chawri Bazar                      15.3
# 9          10                      Maya Puri                      12.8
#
#            Line Opening Date Station Layout   Latitude  Longitude
# 0      Red line   2008-04-06       Elevated  28.675790  77.312390
# 1     Pink line   2018-10-31       Elevated  28.671800  77.277560
# 2   Rapid Metro   2013-11-14       Elevated  28.493600  77.093500
# 3  Magenta line   2017-12-25       Elevated  28.554483  77.264849
# 4     Blue line   2005-12-30       Elevated  28.619320  77.033260
# 5     Pink line   2018-06-08    Underground  28.574408  77.210241
# 6     Aqua line   2019-01-25       Elevated  28.502663  77.426256
# 7   Voilet line   2010-03-10       Elevated  28.564170  77.234230
# 8   Yellow line   2005-03-07    Underground  28.649310  77.226370
# 9     Pink line   2018-03-14       Elevated  28.637179  77.129733

# %%
df.shape
# Out:
# (285, 8)

# %%
df.columns
# Out:
# Index(['Station ID', 'Station Name', 'Distance from Start (km)', 'Line',
#        'Opening Date', 'Station Layout', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Station ID                    int64
# Station Name                 object
# Distance from Start (km)    float64
# Line                         object
# Opening Date                 object
# Station Layout               object
# Latitude                    float64
# Longitude                   float64
# dtype: object

# %%
df.describe()
# Out:
#        Station ID  Distance from Start (km)    Latitude   Longitude
# count  285.000000                285.000000  285.000000  285.000000
# mean   143.000000                 19.218947   28.595428   77.029315
# std     82.416625                 14.002862    0.091316    2.875400
# min      1.000000                  0.000000   27.920862   28.698807
# 25%     72.000000                  7.300000   28.545828   77.107130
# 50%    143.000000                 17.400000   28.613453   77.207220
# 75%    214.000000                 28.800000   28.666360   77.281165
# max    285.000000                 52.700000   28.878965   77.554479

# %%
df.isnull().sum()
# Out:
# Station ID                  0
# Station Name                0
# Distance from Start (km)    0
# Line                        0
# Opening Date                0
# Station Layout              0
# Latitude                    0
# Longitude                   0
# dtype: int64

# %%
from datetime import datetime, date, time

# %%
df['Opening Date'] = pd.to_datetime(df['Opening Date'])

# %%
df.dtypes
# Out:
# Station ID                           int64
# Station Name                        object
# Distance from Start (km)           float64
# Line                                object
# Opening Date                datetime64[ns]
# Station Layout                      object
# Latitude                           float64
# Longitude                          float64
# dtype: object

# %%
line_colors = {
    'Red line': 'red',
    'Blue line': 'blue',
    'Yellow line': 'beige',
    'Green line': 'green',
    'Voilet line': 'purple',
    'Pink line': 'pink',
    'Magenta line': 'darkred',
    'Orange line': 'orange',
    'Rapid Metro': 'cadetblue',
    'Aqua line': 'black',
    'Green line branch': 'lightgreen',
    'Blue line branch': 'lightblue',
    'Gray line': 'lightgray'
}

df_map = folium.Map(location=[28.7041, 77.1025],zoom_start=10)
for index, row in df.iterrows():
    line = row['Line']
    color = line_colors.get(line,'black')
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Station Name']}",
        tooltip=f"{row['Station Name']}, {line}",
        icon=folium.Icon(color=color)
    ).add_to(df_map)

# %%
df_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae162b37387cbc267b41efc47ce9f193 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae162b37387cbc267b41efc47ce9f193&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae162b37387cbc267b41efc47ce9f193 = L.map(
#                 &quot;map_ae162b37387cbc267b41efc47ce9f193&quot;,
#                 {
#                     center: [28.7041, 77.1025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c55008f02bc1ff09bfd50b2e3bef73cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c55008f02bc1ff09bfd50b2e3bef73cc.addTo(map_ae162b37387cbc267b41efc47ce9f193);
#
#
#             var marker_670412cedb4b8a1c0778822938c3c50f = L.marker(
#                 [28.67579, 77.31239],
#                 {}
#             ).addTo(map_ae162b37387cbc267b41efc47ce9f193);
#
#
#             var icon_aab51c884df7cebf349b51c7c2414dc5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_670412cedb4b8a1c0778822938c3c50f.setIcon(icon_aab51c884df7cebf349b51c7c2414dc5);
#
#
#         var popup_629214521fd6cce0f180825fbcccb573 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abc8c78a54bdaf31e08c61993d89e440 = $(`&lt;div id=&quot;html_abc8c78a54bdaf31e08c61993d89e440&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jhil Mil&lt;/div&gt;`)[0];
#                 popup_629214521fd6cce0f180825fbcccb573.setContent(html_abc8c78a54bdaf31e08c61993d89e440);
#
#
#
#         marker_670412cedb4b8a1c0778822938c3c50f.bindPopup(popup_629214521fd6cce0f180825fbcccb573)
#         ;
#
#
#
#
#             marker_670412cedb4b8a1c0778822938c3c50f.bindTooltip(
#                 `&lt;div&gt;
#                      Jhil Mil, Red line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_db0dcaba011135c66957acda8bf1184a = L.marker(
#                 [28.6718, 77.27756],
#                 {}
#             ).addTo(map_ae162b37387cbc267b41efc47ce9f193);
#
#
#             var icon_808abc262deeeaf65240fc32aebb4e05 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db0dcaba011135c66957acda8bf1184a.setIcon(icon_808abc262deeeaf65240fc32aebb4e05);
#
#
#         var popup_747ed6601ae961dfde69d45c9751c352 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19282978b082b39a7d2f9d797d5b0e2e = $(`&lt;div id=&quot;html_19282978b082b39a7d2f9d797d5b0e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome [Conn: Red]&lt;/div&gt;`)[0];
#                 popup_747ed6601ae961dfde69d45c9751c352.setContent(html_19282978b082b39a7d2f9d797d5b0e2e);
#
#
#
#         marker_db0dcaba011135c66957acda8bf1184a.bindPopup(popup_747ed6601ae961dfde69d45c9751c352)
#         ;
#
#
#
#
#             marker_db0dcaba011135c66957acda8bf1184a.bindTooltip(
#                 `&lt;div&gt;
#                      Welcome [Conn: Red], Pink line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4a7c21fe8015d4b8caeb5f6dbd5b924d = L.marker(
#                 [28.4936, 77.0935],
#                 {}
#             ).addTo(map_ae162b37387cbc267b41efc47ce9f193);
#
#
#             var icon_142c3cb14b866be851a812c1f8f3a790 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a7c21fe8015d4b8caeb5f6dbd5b924d.setIcon(icon_142c3cb14b866be851a812c1f8f3a790);
#
#
#         var popup_78c198f94cb8d5ff9d0d4fbd26f81e28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e29d71bd9701ac4b745f2fc97fc18f56 = $(`&lt;div id=&quot;html_e29d71bd9701ac4b745f2fc97fc18f56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DLF Phase 3&lt;/div&gt;`)[0];
#                 popup_78c198f94cb8d5ff9d0d4fbd26f81e28.setContent(html_e29d71bd9701ac4b745f2fc97fc18f56);
#
#
#
#         marker_4a7c21fe8015d4b8caeb5f6dbd5b924d.bindPopup(popup_78c198f94cb8d5ff9d0d4fbd26f

# %%
df.columns
# Out:
# Index(['Station ID', 'Station Name', 'Distance from Start (km)', 'Line',
#        'Opening Date', 'Station Layout', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#extracting the year from "Opening Date" column. 
df['Opening Year'] = df['Opening Date'].dt.year

# %%
df.head()
# Out:
#    Station ID         Station Name  Distance from Start (km)          Line  \
# 0           1             Jhil Mil                      10.3      Red line
# 1           2  Welcome [Conn: Red]                      46.8     Pink line
# 2           3          DLF Phase 3                      10.0   Rapid Metro
# 3           4           Okhla NSIC                      23.8  Magenta line
# 4           5           Dwarka Mor                      10.2     Blue line
#
#   Opening Date Station Layout   Latitude  Longitude  Opening Year
# 0   2008-04-06       Elevated  28.675790  77.312390          2008
# 1   2018-10-31       Elevated  28.671800  77.277560          2018
# 2   2013-11-14       Elevated  28.493600  77.093500          2013
# 3   2017-12-25       Elevated  28.554483  77.264849          2017
# 4   2005-12-30       Elevated  28.619320  77.033260          2005

# %%
#counting the number of stations opened each year
stations_per_year = df['Opening Year'].value_counts().sort_index()

# %%
stations_per_year.sort_values()
# Out:
# Opening Year
# 2008     3
# 2014     3
# 2003     4
# 2013     5
# 2002     6
# 2006     9
# 2004    11
# 2011    13
# 2015    13
# 2009    17
# 2017    18
# 2005    28
# 2019    37
# 2010    54
# 2018    64
# Name: count, dtype: int64

# %%
df_station_per_year = stations_per_year.reset_index()
df_station_per_year
# Out:
#     Opening Year  count
# 0           2002      6
# 1           2003      4
# 2           2004     11
# 3           2005     28
# 4           2006      9
# 5           2008      3
# 6           2009     17
# 7           2010     54
# 8           2011     13
# 9           2013      5
# 10          2014      3
# 11          2015     13
# 12          2017     18
# 13          2018     64
# 14          2019     37

# %%
df_station_per_year.columns=['Year', 'Number of Stations']
df_station_per_year
# Out:
#     Year  Number of Stations
# 0   2002                   6
# 1   2003                   4
# 2   2004                  11
# 3   2005                  28
# 4   2006                   9
# 5   2008                   3
# 6   2009                  17
# 7   2010                  54
# 8   2011                  13
# 9   2013                   5
# 10  2014                   3
# 11  2015                  13
# 12  2017                  18
# 13  2018                  64
# 14  2019                  37

# %%
fig = px.bar(df_station_per_year, x='Year', y='Number of Stations',
             title = "Number of Metro Stations Opened Each Year in Delhi",
             labels={'Year': 'Year', 'Nuber of Stations':'Number of Stations Opened'}             
             )
fig.show()

# %%
#counting the number of stations opened per line
stations_per_line =df["Line"].value_counts().sort_values()
stations_per_line
# Out:
# Line
# Gray line             3
# Green line branch     3
# Orange line           6
# Blue line branch      8
# Rapid Metro          11
# Aqua line            21
# Green line           21
# Magenta line         25
# Red line             29
# Voilet line          34
# Yellow line          37
# Pink line            38
# Blue line            49
# Name: count, dtype: int64

# %%
total_distance_per_line = df.groupby('Line')['Distance from Start (km)'].max()
total_distance_per_line.sort_values()
# Out:
# Line
# Green line branch     2.1
# Gray line             3.9
# Blue line branch      8.1
# Rapid Metro          10.0
# Orange line          20.8
# Green line           24.8
# Aqua line            27.1
# Red line             32.7
# Magenta line         33.1
# Voilet line          43.5
# Yellow line          45.7
# Pink line            52.6
# Blue line            52.7
# Name: Distance from Start (km), dtype: float64

# %%
avg_distance_per_line = total_distance_per_line / (stations_per_line -1)
avg_distance_per_line
# Out:
# Line
# Aqua line            1.355000
# Blue line            1.097917
# Blue line branch     1.157143
# Gray line            1.950000
# Green line           1.240000
# Green line branch    1.050000
# Magenta line         1.379167
# Orange line          4.160000
# Pink line            1.421622
# Rapid Metro          1.000000
# Red line             1.167857
# Voilet line          1.318182
# Yellow line          1.269444
# dtype: float64

# %%
line_analysis = pd.DataFrame({
    "Line" : stations_per_line.index,
    "Number of Stations" : stations_per_line.values,
    "Avg Distance Between Stations (km)" : avg_distance_per_line
})

# %%
line_analysis
# Out:
#                                 Line  Number of Stations  \
# Line
# Aqua line                  Gray line                   3
# Blue line          Green line branch                   3
# Blue line branch         Orange line                   6
# Gray line           Blue line branch                   8
# Green line               Rapid Metro                  11
# Green line branch          Aqua line                  21
# Magenta line              Green line                  21
# Orange line             Magenta line                  25
# Pink line                   Red line                  29
# Rapid Metro              Voilet line                  34
# Red line                 Yellow line                  37
# Voilet line                Pink line                  38
# Yellow line                Blue line                  49
#
#                    Avg Distance Between Stations (km)
# Line
# Aqua line                                    1.355000
# Blue line                                    1.097917
# Blue line branch                             1.157143
# Gray line                                    1.950000
# Green line                                   1.240000
# Green line branch                            1.050000
# Magenta line                                 1.379167
# Orange line                                  4.160000
# Pink line                                    1.421622
# Rapid Metro                                  1.000000
# Red line                                     1.167857
# Voilet line                                  1.318182
# Yellow line                                  1.269444

# %%
line_analysis.reset_index(drop=True, inplace = True)
line_analysis
# Out:
#                  Line  Number of Stations  Avg Distance Between Stations (km)
# 0           Gray line                   3                            1.355000
# 1   Green line branch                   3                            1.097917
# 2         Orange line                   6                            1.157143
# 3    Blue line branch                   8                            1.950000
# 4         Rapid Metro                  11                            1.240000
# 5           Aqua line                  21                            1.050000
# 6          Green line                  21                            1.379167
# 7        Magenta line                  25                            4.160000
# 8            Red line                  29                            1.421622
# 9         Voilet line                  34                            1.000000
# 10        Yellow line                  37                            1.167857
# 11          Pink line                  38                            1.318182
# 12          Blue line                  49                            1.269444

# %%
fig = px.bar(
    line_analysis, x="Line", y="Number of Stations",
    title = "Number of Stations per Line"
)
fig.show()

# %%
fig = px.bar(
    line_analysis, x="Line", y="Avg Distance Between Stations (km)",
    title = "Average Distance per Station Line (km)"
)
fig.show()

# %%
df.head(5)
# Out:
#    Station ID         Station Name  Distance from Start (km)          Line  \
# 0           1             Jhil Mil                      10.3      Red line
# 1           2  Welcome [Conn: Red]                      46.8     Pink line
# 2           3          DLF Phase 3                      10.0   Rapid Metro
# 3           4           Okhla NSIC                      23.8  Magenta line
# 4           5           Dwarka Mor                      10.2     Blue line
#
#   Opening Date Station Layout   Latitude  Longitude  Opening Year
# 0   2008-04-06       Elevated  28.675790  77.312390          2008
# 1   2018-10-31       Elevated  28.671800  77.277560          2018
# 2   2013-11-14       Elevated  28.493600  77.093500          2013
# 3   2017-12-25       Elevated  28.554483  77.264849          2017
# 4   2005-12-30       Elevated  28.619320  77.033260          2005

# %%
df['Station Layout'].value_counts()
# Out:
# Station Layout
# Elevated       214
# Underground     68
# At-Grade         3
# Name: count, dtype: int64

# %%
station_layout_counts = df['Station Layout'].value_counts()
station_layout_counts
# Out:
# Station Layout
# Elevated       214
# Underground     68
# At-Grade         3
# Name: count, dtype: int64

# %%
colors = ['lightblue', 'wheat', 'red']
fig = px.bar(
            station_layout_counts, 
            x=station_layout_counts.index, 
            y=station_layout_counts.values,
            labels={'y':"Number of Stations", 'x':'Station Layout'},
            color = station_layout_counts.index,
            color_discrete_sequence = colors
)

fig.update_layout(
    title ="Delhi Metro Station Layouts",    
)
fig.show()
